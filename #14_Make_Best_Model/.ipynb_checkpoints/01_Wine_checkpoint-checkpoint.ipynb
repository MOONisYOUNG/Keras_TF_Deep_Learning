# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import ModelCheckpoint

import pandas as pd
import numpy
import os
import tensorflow as tf

# %%
numpy.random.seed(3)
tf.random.set_seed(3)

df_pre = pd.read_csv('../dataset/wine.csv', header=None)
df = df_pre.sample(frac=1)

dataset = df.values
X = dataset[:, 0:12]
Y = dataset[:, 12]

model = Sequential()
model.add(Dense(30, input_dim=12, activation='relu'))
model.add(Dense(12, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

MODEL_DIR = './code_01_model_result/'
if not os.path.exists(MODEL_DIR):
    os.mkdir(MODEL_DIR)
    
modelpath = "./code_01_model_result/{epoch:02d}-{val_loss:.4f}.hdf5"
checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss', verbose=1,
                              save_best_only=True)

model.fit(X, Y, validation_split=0.2, epochs=200, batch_size=200, 
          verbose=0, callbacks=[checkpointer])
# Out:
# Epoch 1: val_loss improved from inf to 0.29002, saving model to ./code_01_model_result\01-0.2900.hdf5
#
# Epoch 2: val_loss improved from 0.29002 to 0.26893, saving model to ./code_01_model_result\02-0.2689.hdf5
#
# Epoch 3: val_loss improved from 0.26893 to 0.25161, saving model to ./code_01_model_result\03-0.2516.hdf5
#
# Epoch 4: val_loss improved from 0.25161 to 0.23818, saving model to ./code_01_model_result\04-0.2382.hdf5
#
# Epoch 5: val_loss improved from 0.23818 to 0.22936, saving model to ./code_01_model_result\05-0.2294.hdf5
#
# Epoch 6: val_loss improved from 0.22936 to 0.21826, saving model to ./code_01_model_result\06-0.2183.hdf5
#
# Epoch 7: val_loss improved from 0.21826 to 0.20653, saving model to ./code_01_model_result\07-0.2065.hdf5
#
# Epoch 8: val_loss improved from 0.20653 to 0.19478, saving model to ./code_01_model_result\08-0.1948.hdf5
#
# Epoch 9: val_loss improved from 0.19478 to 0.18846, saving model to ./code_01_model_result\09-0.1885.hdf5
#
# Epoch 10: val_loss improved from 0.18846 to 0.18836, saving model to ./code_01_model_result\10-0.1884.hdf5
#
# Epoch 11: val_loss improved from 0.18836 to 0.18207, saving model to ./code_01_model_result\11-0.1821.hdf5
#
# Epoch 12: val_loss improved from 0.18207 to 0.17590, saving model to ./code_01_model_result\12-0.1759.hdf5
#
# Epoch 13: val_loss improved from 0.17590 to 0.15570, saving model to ./code_01_model_result\13-0.1557.hdf5
#
# Epoch 14: val_loss improved from 0.15570 to 0.14159, saving model to ./code_01_model_result\14-0.1416.hdf5
#
# Epoch 15: val_loss improved from 0.14159 to 0.13524, saving model to ./code_01_model_result\15-0.1352.hdf5
#
# Epoch 16: val_loss did not improve from 0.13524
#
# Epoch 17: val_loss improved from 0.13524 to 0.12007, saving model to ./code_01_model_result\17-0.1201.hdf5
#
# Epoch 18: val_loss improved from 0.12007 to 0.11676, saving model to ./code_01_model_result\18-0.1168.hdf5
#
# Epoch 19: val_loss improved from 0.11676 to 0.11059, saving model to ./code_01_model_result\19-0.1106.hdf5
#
# Epoch 20: val_loss improved from 0.11059 to 0.10885, saving model to ./code_01_model_result\20-0.1088.hdf5
#
# Epoch 21: val_loss improved from 0.10885 to 0.10619, saving model to ./code_01_model_result\21-0.1062.hdf5
#
# Epoch 22: val_loss improved from 0.10619 to 0.10317, saving model to ./code_01_model_result\22-0.1032.hdf5
#
# Epoch 23: val_loss did not improve from 0.10317
#
# Epoch 24: val_loss did not improve from 0.10317
#
# Epoch 25: val_loss improved from 0.10317 to 0.09698, saving model to ./code_01_model_result\25-0.0970.hdf5
#
# Epoch 26: val_loss improved from 0.09698 to 0.09677, saving model to ./code_01_model_result\26-0.0968.hdf5
#
# Epoch 27: val_loss improved from 0.09677 to 0.09106, saving model to ./code_01_model_result\27-0.0911.hdf5
#
# Epoch 28: val_loss improved from 0.09106 to 0.08822, saving model to ./code_01_model_result\28-0.0882.hdf5
#
# Epoch 29: val_loss improved from 0.08822 to 0.08708, saving model to ./code_01_model_result\29-0.0871.hdf5
#
# Epoch 30: val_loss improved from 0.08708 to 0.08668, saving model to ./code_01_model_result\30-0.0867.hdf5
#
# Epoch 31: val_loss improved from 0.08668 to 0.08273, saving model to ./code_01_model_result\31-0.0827.hdf5
#
# Epoch 32: val_loss did not improve from 0.08273
#
# Epoch 33: val_loss improved from 0.08273 to 0.08016, saving model to ./code_01_model_result\33-0.0802.hdf5
#
# Epoch 34: val_loss improved from 0.08016 to 0.07867, saving model to ./code_01_model_result\34-0.0787.hdf5
#
# Epoch 35: val_loss improved from 0.07867 to 0.07766, saving model to ./code_01_model_result\35-0.0777.hdf5
#
# Epoch 36: val_loss did not improve from 0.07766
#
# Epoch 37: val_loss improved from 0.07766 to 0.07561, saving model to ./code_01_model_result\37-0.0756.hdf5
#
# Epoch 38: val_loss did not improve from 0.07561
#
# Epoch 39: val_loss improved from 0.07561 to 0.07260, saving model to ./code_01_model_result\39-0.0726.hdf5
#
# Epoch 40: val_loss did not improve from 0.07260
#
# Epoch 41: val_loss improved from 0.07260 to 0.07188, saving model to ./code_01_model_result\41-0.0719.hdf5
#
# Epoch 42: val_loss did not improve from 0.07188
#
# Epoch 43: val_loss improved from 0.07188 to 0.06882, saving model to ./code_01_model_result\43-0.0688.hdf5
#
# Epoch 44: val_loss did not improve from 0.06882
#
# Epoch 45: val_loss did not improve from 0.06882
#
# Epoch 46: val_loss improved from 0.06882 to 0.06669, saving model to ./code_01_model_result\46-0.0667.hdf5
#
# Epoch 47: val_loss improved from 0.06669 to 0.06630, saving model to ./code_01_model_result\47-0.0663.hdf5
#
# Epoch 48: val_loss improved from 0.06630 to 0.06538, saving model to ./code_01_model_result\48-0.0654.hdf5
#
# Epoch 49: val_loss did not improve from 0.06538
#
# Epoch 50: val_loss did not improve from 0.06538
#
# Epoch 51: val_loss improved from 0.06538 to 0.06485, saving model to ./code_01_model_result\51-0.0649.hdf5
#
# Epoch 52: val_loss did not improve from 0.06485
#
# Epoch 53: val_loss did not improve from 0.06485
#
# Epoch 54: val_loss improved from 0.06485 to 0.06171, saving model to ./code_01_model_result\54-0.0617.hdf5
#
# Epoch 55: val_loss did not improve from 0.06171
#
# Epoch 56: val_loss did not improve from 0.06171
#
# Epoch 57: val_loss improved from 0.06171 to 0.06155, saving model to ./code_01_model_result\57-0.0615.hdf5
#
# Epoch 58: val_loss improved from 0.06155 to 0.06092, saving model to ./code_01_model_result\58-0.0609.hdf5
#
# Epoch 59: val_loss did not improve from 0.06092
#
# Epoch 60: val_loss improved from 0.06092 to 0.06048, saving model to ./code_01_model_result\60-0.0605.hdf5
#
# Epoch 61: val_loss did not improve from 0.06048
#
# Epoch 62: val_loss did not improve from 0.06048
#
# Epoch 63: val_loss did not improve from 0.06048
#
# Epoch 64: val_loss improved from 0.06048 to 0.05955, saving model to ./code_01_model_result\64-0.0595.hdf5
#
# Epoch 65: val_loss improved from 0.05955 to 0.05810, saving model to ./code_01_model_result\65-0.0581.hdf5
#
# Epoch 66: val_loss did not improve from 0.05810
#
# Epoch 67: val_loss improved from 0.05810 to 0.05666, saving model to ./code_01_model_result\67-0.0567.hdf5
#
# Epoch 68: val_loss did not improve from 0.05666
#
# Epoch 69: val_loss improved from 0.05666 to 0.05585, saving model to ./code_01_model_result\69-0.0558.hdf5
#
# Epoch 70: val_loss did not improve from 0.05585
#
# Epoch 71: val_loss did not improve from 0.05585
#
# Epoch 72: val_loss did not improve from 0.05585
#
# Epoch 73: val_loss did not improve from 0.05585
#
# Epoch 74: val_loss did not improve from 0.05585
#
# Epoch 75: val_loss did not improve from 0.05585
#
# Epoch 76: val_loss did not improve from 0.05585
#
# Epoch 77: val_loss did not improve from 0.05585
#
# Epoch 78: val_loss did not improve from 0.05585
#
# Epoch 79: val_loss did not improve from 0.05585
#
# Epoch 80: val_loss did not improve from 0.05585
#
# Epoch 81: val_loss improved from 0.05585 to 0.05528, saving model to ./code_01_model_result\81-0.0553.hdf5
#
# Epoch 82: val_loss did not improve from 0.05528
#
# Epoch 83: val_loss improved from 0.05528 to 0.05431, saving model to ./code_01_model_result\83-0.0543.hdf5
#
# Epoch 84: val_loss improved from 0.05431 to 0.05394, saving model to ./code_01_model_result\84-0.0539.hdf5
#
# Epoch 85: val_loss did not improve from 0.05394
#
# Epoch 86: val_loss did not improve from 0.05394
#
# Epoch 87: val_loss did not improve from 0.05394
#
# Epoch 88: val_loss did not improve from 0.05394
#
# Epoch 89: val_loss improved from 0.05394 to 0.05357, saving model to ./code_01_model_result\89-0.0536.hdf5
#
# Epoch 90: val_loss did not improve from 0.05357
#
# Epoch 91: val_loss improved from 0.05357 to 0.05323, saving model to ./code_01_model_result\91-0.0532.hdf5
#
# Epoch 92: val_loss did not improve from 0.05323
#
# Epoch 93: val_loss did not improve from 0.05323
#
# Epoch 94: val_loss did not improve from 0.05323
#
# Epoch 95: val_loss improved from 0.05323 to 0.05261, saving model to ./code_01_model_result\95-0.0526.hdf5
#
# Epoch 96: val_loss did not improve from 0.05261
#
# Epoch 97: val_loss did not improve from 0.05261
#
# Epoch 98: val_loss did not improve from 0.05261
#
# Epoch 99: val_loss improved from 0.05261 to 0.05240, saving model to ./code_01_model_result\99-0.0524.hdf5
#
# Epoch 100: val_loss improved from 0.05240 to 0.05227, saving model to ./code_01_model_result\100-0.0523.hdf5
#
# Epoch 101: val_loss did not improve from 0.05227
#
# Epoch 102: val_loss did not improve from 0.05227
# Epoch 103: val_loss improved from 0.05227 to 0.05186, saving model to ./code_01_model_result\103-0.0519.hdf5
#
# Epoch 104: val_loss did not improve from 0.05186
#
# Epoch 105: val_loss did not improve from 0.05186
#
# Epoch 106: val_loss did not improve from 0.05186
#
# Epoch 107: val_loss did not improve from 0.05186
#
# Epoch 108: val_loss improved from 0.05186 to 0.05178, saving model to ./code_01_model_result\108-0.0518.hdf5
#
# Epoch 109: val_loss improved from 0.05178 to 0.05114, saving model to ./code_01_model_result\109-0.0511.hdf5
#
# Epoch 110: val_loss did not improve from 0.05114
#
# Epoch 111: val_loss did not improve from 0.05114
#
# Epoch 112: val_loss did not improve from 0.05114
#
# Epoch 113: val_loss did not improve from 0.05114
#
# Epoch 114: val_loss did not improve from 0.05114
#
# Epoch 115: val_loss did not improve from 0.05114
#
# Epoch 116: val_loss did not improve from 0.05114
#
# Epoch 117: val_loss improved from 0.05114 to 0.05067, saving model to ./code_01_model_result\117-0.0507.hdf5
#
# Epoch 118: val_loss did not improve from 0.05067
#
# Epoch 119: val_loss did not improve from 0.05067
#
# Epoch 120: val_loss did not improve from 0.05067
#
# Epoch 121: val_loss did not improve from 0.05067
#
# Epoch 122: val_loss did not improve from 0.05067
#
# Epoch 123: val_loss improved from 0.05067 to 0.05013, saving model to ./code_01_model_result\123-0.0501.hdf5
#
# Epoch 124: val_loss did not improve from 0.05013
#
# Epoch 125: val_loss did not improve from 0.05013
#
# Epoch 126: val_loss did not improve from 0.05013
#
# Epoch 127: val_loss did not improve from 0.05013
#
# Epoch 128: val_loss did not improve from 0.05013
#
# Epoch 129: val_loss did not improve from 0.05013
#
# Epoch 130: val_loss did not improve from 0.05013
#
# Epoch 131: val_loss did not improve from 0.05013
#
# Epoch 132: val_loss did not improve from 0.05013
#
# Epoch 133: val_loss did not improve from 0.05013
#
# Epoch 134: val_loss did not improve from 0.05013
#
# Epoch 135: val_loss did not improve from 0.05013
#
# Epoch 136: val_loss improved from 0.05013 to 0.04991, saving model to ./code_01_model_result\136-0.0499.hdf5
#
# Epoch 137: val_loss improved from 0.04991 to 0.04936, saving model to ./code_01_model_result\137-0.0494.hdf5
#
# Epoch 138: val_loss did not improve from 0.04936
#
# Epoch 139: val_loss did not improve from 0.04936
#
# Epoch 140: val_loss did not improve from 0.04936
#
# Epoch 141: val_loss did not improve from 0.04936
#
# Epoch 142: val_loss did not improve from 0.04936
#
# Epoch 143: val_loss improved from 0.04936 to 0.04918, saving model to ./code_01_model_result\143-0.0492.hdf5
#
# Epoch 144: val_loss did not improve from 0.04918
#
# Epoch 145: val_loss did not improve from 0.04918
#
# Epoch 146: val_loss did not improve from 0.04918
#
# Epoch 147: val_loss did not improve from 0.04918
#
# Epoch 148: val_loss did not improve from 0.04918
#
# Epoch 149: val_loss did not improve from 0.04918
#
# Epoch 150: val_loss did not improve from 0.04918
#
# Epoch 151: val_loss did not improve from 0.04918
#
# Epoch 152: val_loss improved from 0.04918 to 0.04850, saving model to ./code_01_model_result\152-0.0485.hdf5
#
# Epoch 153: val_loss did not improve from 0.04850
#
# Epoch 154: val_loss did not improve from 0.04850
#
# Epoch 155: val_loss did not improve from 0.04850
#
# Epoch 156: val_loss did not improve from 0.04850
#
# Epoch 157: val_loss did not improve from 0.04850
#
# Epoch 158: val_loss did not improve from 0.04850
#
# Epoch 159: val_loss did not improve from 0.04850
#
# Epoch 160: val_loss did not improve from 0.04850
#
# Epoch 161: val_loss did not improve from 0.04850
#
# Epoch 162: val_loss did not improve from 0.04850
#
# Epoch 163: val_loss did not improve from 0.04850
#
# Epoch 164: val_loss did not improve from 0.04850
#
# Epoch 165: val_loss did not improve from 0.04850
#
# Epoch 166: val_loss did not improve from 0.04850
#
# Epoch 167: val_loss did not improve from 0.04850
#
# Epoch 168: val_loss improved from 0.04850 to 0.04793, saving model to ./code_01_model_result\168-0.0479.hdf5
#
# Epoch 169: val_loss did not improve from 0.04793
#
# Epoch 170: val_loss did not improve from 0.04793
#
# Epoch 171: val_loss did not improve from 0.04793
#
# Epoch 172: val_loss did not improve from 0.04793
#
# Epoch 173: val_loss improved from 0.04793 to 0.04767, saving model to ./code_01_model_result\173-0.0477.hdf5
#
# Epoch 174: val_loss did not improve from 0.04767
#
# Epoch 175: val_loss did not improve from 0.04767
#
# Epoch 176: val_loss did not improve from 0.04767
#
# Epoch 177: val_loss did not improve from 0.04767
#
# Epoch 178: val_loss did not improve from 0.04767
#
# Epoch 179: val_loss did not improve from 0.04767
#
# Epoch 180: val_loss did not improve from 0.04767
#
# Epoch 181: val_loss did not improve from 0.04767
#
# Epoch 182: val_loss did not improve from 0.04767
#
# Epoch 183: val_loss improved from 0.04767 to 0.04736, saving model to ./code_01_model_result\183-0.0474.hdf5
#
# Epoch 184: val_loss did not improve from 0.04736
#
# Epoch 185: val_loss did not improve from 0.04736
#
# Epoch 186: val_loss did not improve from 0.04736
#
# Epoch 187: val_loss did not improve from 0.04736
#
# Epoch 188: val_loss did not improve from 0.04736
#
# Epoch 189: val_loss did not improve from 0.04736
#
# Epoch 190: val_loss did not improve from 0.04736
#
# Epoch 191: val_loss did not improve from 0.04736
#
# Epoch 192: val_loss did not improve from 0.04736
#
# Epoch 193: val_loss did not improve from 0.04736
#
# Epoch 194: val_loss did not improve from 0.04736
#
# Epoch 195: val_loss did not improve from 0.04736
#
# Epoch 196: val_loss did not improve from 0.04736
#
# Epoch 197: val_loss did not improve from 0.04736
#
# Epoch 198: val_loss did not improve from 0.04736
#
# Epoch 199: val_loss did not improve from 0.04736
#
# Epoch 200: val_loss did not improve from 0.04736
